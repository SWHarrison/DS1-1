# %%
import numpy as np
import pandas as pd

df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1145cc940>,
# ...
#       dtype=object)

# %%
df.Age.hist(bins = 80)

# %%
df[(df["Sex"] == "female")].Age.hist(bins = 16)

# %%
df[(df["Sex"] == "male")].Age.hist(bins = 16)

# %%
df.Age.isna().sum()
# Out:
# 177

# %%
def _gender_return(data):
    if(data == 'female'):
        return 0
    else:
        return 1

df["gender"] = df["Sex"].apply(_gender_return)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.Age.plot.box()

# %%
df[df.Sex == 'female'].Age.plot.box()

# %%
df[df.Sex == 'male'].Age.plot.box()

# %%
df[df.Age.isna() == False]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 30            31         0       1
# ...

# %%
df.Age.dropna().values
# Out:
# array([22.  , 38.  , 26.  , 35.  , 35.  , 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  , 31.  , 35.  ,
#        34.  , 15.  , 28.  ,  8.  , 38.  , 19.  , 40.  , 66.  , 28.  ,
#        42.  , 21.  , 18.  , 14.  , 40.  , 27.  ,  3.  , 19.  , 18.  ,
#         7.  , 21.  , 49.  , 29.  , 65.  , 21.  , 28.5 ,  5.  , 11.  ,
#        22.  , 38.  , 45.  ,  4.  , 29.  , 19.  , 17.  , 26.  , 32.  ,
#        16.  , 21.  , 26.  , 32.  , 25.  ,  0.83, 30.  , 22.  , 29.  ,
#        28.  , 17.  , 33.  , 16.  , 23.  , 24.  , 29.  , 20.  , 46.  ,
#        26.  , 59.  , 71.  , 23.  , 34.  , 34.  , 28.  , 21.  , 33.  ,
#        37.  , 28.  , 21.  , 38.  , 47.  , 14.5 , 22.  , 20.  , 17.  ,
#        21.  , 70.5 , 29.  , 24.  ,  2.  , 21.  , 32.5 , 32.5 , 54.  ,
#        12.  , 24.  , 45.  , 33.  , 20.  , 47.  , 29.  , 25.  , 23.  ,
#        19.  , 37.  , 16.  , 24.  , 22.  , 24.  , 19.  , 18.  , 19.  ,
# ...

# %%
df[df.Embarked == 'C'].Age.plot.box()

# %%
df[df.Embarked == 'C'].Age.hist(bins = 16)

# %%
df[df.Embarked == 'C'].Age.hist(bins = 80)

# %%
'''Q = len(df[df.Embarked == 'Q'])
C = len(df[df.Embarked == 'C'])
S = len(df[df.Embarked == 'S'])
print(Q);
df.plot.bar(x='Embarked', y=, rot=0)
This cannot work because it expects the values in the dataframe, but we need to find the values for each port.'''
# Out:
# "Q = len(df[df.Embarked == 'Q'])\nC = len(df[df.Embarked == 'C'])\nS = len(df[df.Embarked == 'S'])\nprint(Q);\ndf.plot.bar(x='Embarked', y=, rot=0)\nThis cannot work because it expects the values in the dataframe, but we need to find the values for each port."

# %%
df.Embarked.value_counts().plot(kind='bar')

# %%
import seaborn as sns
sns.countplot(x='Embarked', palette='cubehelix', data=df)

# %%
df[df['Embarked'] == 'C'].groupby('Sex')['Age'].plot(bins=16, kind='hist', legend=True, alpha=0.5)
# Out:
# Sex
# female    AxesSubplot(0.125,0.125;0.775x0.755)
# male      AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Age, dtype: object

# %%
df[(df.Embarked == 'C') & (df.Sex == 'female')].mean()
# Out:
# PassengerId    437.315068
# Survived         0.876712
# Pclass           1.726027
# Age             28.344262
# SibSp            0.547945
# Parch            0.493151
# Fare            75.169805
# gender           0.000000
# dtype: float64

# %%
df[(df.Embarked == 'C') & (df.Sex == 'male')].mean()
# Out:
# PassengerId    451.536842
# Survived         0.305263
# Pclass           2.010526
# Age             32.998841
# SibSp            0.263158
# Parch            0.263158
# Fare            48.262109
# gender           1.000000
# dtype: float64

# %%
df[df.Embarked == 'C'].groupby('Sex').Age.mean()
# Out:
# Sex
# female    28.344262
# male      32.998841
# Name: Age, dtype: float64

# %%
df[df.Embarked == 'C'].groupby('Sex').Age.agg(np.max)
# Out:
# Sex
# female    60.0
# male      71.0
# Name: Age, dtype: float64

# %%
sns.regplot(x="Age", y="Fare", fit_reg=False, data=df)

# %%
df.plot.scatter(x='Age', y='Fare')

# %%
sns.barplot(x='Sex', y='Survived', hue='Pclass', data=df)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x='Survived', y='Sex', hue='Embarked', data=df)

# %%
sns.countplot(x='Sex', hue='Pclass', data=df)

# %%
females = df[df.Sex == 'female']
females
sns.barplot(x='Pclass', y='Survived', data=females)

# %%
df[(df.Sex == 'female') & (df.Pclass == 1)].Survived.value_counts()
# Out:
# 1    91
# 0     3
# Name: Survived, dtype: int64

# %%
df.groupby(['Sex']).Pclass.value_counts().plot(kind='bar', stacked=True)

# %%
df.groupby(['Sex']).Pclass.value_counts().unstack().plot(kind='bar', stacked=True)

# %%
df.groupby(['Sex','Survived']).Pclass.value_counts().unstack().plot(kind='bar', stacked = True)

# %%
pd.crosstab(df.Sex,df.Pclass)
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
sns.heatmap(pd.crosstab(df.Sex, df.Embarked, normalize='index'), cmap='YlGnBu',annot=True)

# %%
adf = pd.DataFrame(data={'x1': ['A', 'B', 'C'], 'x2' : [1, 2, 3]})
bdf = pd.DataFrame(data={'x1': ['A', 'B', 'D'], 'x3' : ['T', 'F', 'T']})

# %%
adf
# Out:
#   x1  x2
# 0  A   1
# 1  B   2
# 2  C   3

# %%
pd.merge(adf,bdf,how='left')
# Out:
#   x1  x2   x3
# 0  A   1    T
# 1  B   2    F
# 2  C   3  NaN

# %%
pd.merge(adf,bdf,how='right')
# Out:
#   x1   x2 x3
# 0  A  1.0  T
# 1  B  2.0  F
# 2  D  NaN  T

# %%
pd.merge(adf,bdf,how='outer')
# Out:
#   x1   x2   x3
# 0  A  1.0    T
# 1  B  2.0    F
# 2  C  3.0  NaN
# 3  D  NaN    T

# %%
pd.concat([adf,bdf],sort=True)
# Out:
#   x1   x2   x3
# 0  A  1.0  NaN
# 1  B  2.0  NaN
# 2  C  3.0  NaN
# 0  A  NaN    T
# 1  B  NaN    F
# 2  D  NaN    T

# %%
pd.concat([adf,bdf],ignore_index=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#   x1   x2   x3
# 0  A  1.0  NaN
# 1  B  2.0  NaN
# 2  C  3.0  NaN
# 3  A  NaN    T
# 4  B  NaN    F
# 5  D  NaN    T

# %%
ls_fare = df.Fare.dropna().values

# %%
ls_fare
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#          8.05  ,  31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,
#         18.    ,   7.225 ,  26.    ,  13.    ,   8.0292,  35.5   ,
#         21.075 ,  31.3875,   7.225 , 263.    ,   7.8792,   7.8958,
#         27.7208, 146.5208,   7.75  ,  10.5   ,  82.1708,  52.    ,
#          7.2292,   8.05  ,  18.    ,  11.2417,   9.475 ,  21.    ,
#          7.8958,  41.5792,   7.8792,   8.05  ,  15.5   ,   7.75  ,
#         21.6792,  17.8   ,  39.6875,   7.8   ,  76.7292,  26.    ,
#         61.9792,  35.5   ,  10.5   ,   7.2292,  27.75  ,  46.9   ,
#          7.2292,  80.    ,  83.475 ,  27.9   ,  27.7208,  15.2458,
#         10.5   ,   8.1583,   7.925 ,   8.6625,  10.5   ,  46.9   ,
#         73.5   ,  14.4542,  56.4958,   7.65  ,   7.8958,   8.05  ,
#         29.    ,  12.475 ,   9.    ,   9.5   ,   7.7875,  47.1   ,
# ...

# %%
sum(ls_fare) / len(ls_fare)
# Out:
# 32.2042079685746

# %%
np.mean(ls_fare)
# Out:
# 32.204207968574636

# %%
len(df[df.Fare < np.mean(ls_fare)]) / len(ls_fare)
# Out:
# 0.7631874298540965

# %%
np.median(ls_fare)
# Out:
# 14.4542

# %%
len(df[df.Fare < np.median(ls_fare)]) / len(ls_fare)
# Out:
# 0.49382716049382713

# %%
numbers_below_percentile = len(df[df.Fare < 31]) / len(ls_fare)

# %%
numbers_below_percentile
# Out:
# 0.7474747474747475

# %%
len(df[df.Survived == 1])
# Out:
# 342

# %%
len(df[(df.Fare > 100) & (df.Survived ==1)]) / len(df[df.Fare > 100])
# Out:
# 0.7358490566037735

# %%
## Chance of a male surviving
len(df[(df.gender == 1) & (df.Survived ==1)]) / len(df[df.gender == 1])
# Out:
# 0.18890814558058924

# %%
# Percentage of survivors that were male
len(df[(df.gender == 1) & (df.Survived == 1)]) / len(df[df.Survived == 1])
# Out:
# 0.31871345029239767

# %%
sns.distplot(df.Age.dropna(), hist = True, kde = True, bins = 20)

# %%
sns.distplot(df.Age.dropna(), hist_kws = dict(cumulative=True), kde_kws = dict(cumulative=True))

# %%
sns.distplot(df[df['Sex'] == 'male']['Age'].dropna(), hist = True, kde = True, bins=20)

# %%
sns.distplot(df[df['Sex'] == 'female']['Age'].dropna(), hist = True, kde= True, bins=20)

# %%
import scipy.stats as st

# %%
st.norm

# %%
st.norm(df)

# %%
print(st.norm.cdf(1) - st.norm.cdf(-1))
# Out:
# 0.6826894921370859

# %%
print(st.norm.cdf(2) - st.norm.cdf(-2))
# Out:
# 0.9544997361036416

# %%
import matplotlib.pyplot as plt

s = np.random.normal(60,10,100000)
plt.hist(s,bins=10)
plt.show()
